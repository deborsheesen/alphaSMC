# %%
# Calling libraries:
from __future__ import division
# %matplotlib inline
import numpy as np,  matplotlib.pyplot as plt
from time import time
from pylab import plot, show, legend
from PF import *
from SV import *
from OU import *
from pseudo_marginal_MH import *
plt.rcParams['figure.figsize'] = (15.0, 3.0)

# %%
x_0 = np.asarray([0])
theta_SV = np.asarray([0.9, 0.25, 0.1])
T = 20
y_SV = simulate_data_SV(theta_SV, x_0, T)
data_SV = dict(x_0=x_0, y=y_SV)

# %%
def log_prior(theta, sd=1e0) :
    return np.sum(-1/(2*sd**2)*theta**2)

# %%
n_iter = 5_000
N = 2*T
scale = 1e-1*np.ones(len(theta_SV))

# %%
chain, accepted, scale = pm_MH(theta_SV, data_SV, n_iter, propose_RW, acceptance_ratio_RW, 
                               scale, log_potential_SV, propagate_SV, N, log_prior, adapt=False, update_dims=[0])
# Out:
#  31%|███       | 1532/5000 [00:04<00:10, 330.78it/s]/home/postdoc/dsen/Desktop/alphaSMC/PF.py:36: RuntimeWarning: overflow encountered in exp
#   weights = np.exp(log_weights-min(log_weights))
# /home/postdoc/dsen/Desktop/alphaSMC/PF.py:39: RuntimeWarning: invalid value encountered in true_divide
#   particles = particles[npr.choice(a=N, size=N, replace=True, p=weights/np.sum(weights))]
# /home/postdoc/dsen/Desktop/alphaSMC/PF.py:39: RuntimeWarning: invalid value encountered in less
#   particles = particles[npr.choice(a=N, size=N, replace=True, p=weights/np.sum(weights))]
# 100%|██████████| 5000/5000 [00:15<00:00, 326.63it/s]

# %%
100*accepted
# Out:
# 27.08

# %%
theta_dim = len(theta_SV)
for i in range(theta_dim) :
    plt.subplot(1,theta_dim,i+1)
    plt.plot(chain[:,i])
    plt.grid(True);

# %%
plt.plot(scale[2000:3000,0])

# %%
scale[2000-1]
# Out:
# array([0.025, 0.025, 0.025])

# %%
xx = npr.rand(3)
a,b,c = xx

# %%
a,b,c
# Out:
# (0.18393534955346635, 0.8089880525823133, 0.3526204370225591)

# %%
norm.logpdf(x=npr.randn(3),loc=np.zeros(3))
# Out:
# array([-1.14036937, -1.19468281, -2.89751296])
